# %% [markdown]
# # 🚀 02 Train
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ritwikareddykancharla/neural-milp-surrogate/blob/main/notebooks/02_train.ipynb)
