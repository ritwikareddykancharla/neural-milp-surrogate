# %% [markdown]
# # 🚀 01 Generate Dataset
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ritwikareddykancharla/neural-milp-surrogate/blob/main/notebooks/01_generate_dataset.ipynb)
